# %%
import bs4
import requests
from lxml import html
import pandas as pd
import re
header = {'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 YaBrowser/21.9.1.600 (beta) Yowser/2.5 Safari/537.36'}

# %%
search = 'тряпка'
url = f'https://www.ozon.ru/search/?from_global=true&deny_category_prediction=true&text=тряпка'
response = requests.get(url, headers=header)
dom = html.fromstring(response.text)
link = dom.xpath("//div[@data-widget='searchResultsV2']/div/div[1]/a")
# links = [link['./a/@href'] for link in dom.xpath("//div[@data-widget='searchResultsV2']/div/div")]

# %%
response.text
# Out:
# '<!DOCTYPE html>\n    <html lang="ru" data-n-head-ssr>\n        <head>\n        \n        \n        \n        \n        <script nonce="3ae6f58e-5623-4a73-be8b-0d8635310291">window.__getPublicPath=function(){return "https://cdn2.ozone.ru/assets/";}</script>\n        <meta charset="utf-8">\n        <meta name="yandex-verification" content="2bccd09858554e85">\n        <meta name="google" content="notranslate">\n        <meta name="referrer" content="no-referrer-when-downgrade">\n        <meta name="yandex-tableau-widget" content="logo=/public/logo2019-y.png, color=#ffffff">\n        <meta nonce="3ae6f58e-5623-4a73-be8b-0d8635310291" name="viewport" data-hid="viewport" content="width=device-width, height=device-height, minimum-scale=1.0, maximum-scale=1.0, initial-scale=1.0">\n        <link rel="icon" type="image/x-icon" href="/public/favicon.ico">\n        <link rel="apple-touch-icon" sizes="152x152" href="/public/touch-icon-ipad-retina.png">\n        <link rel="apple-touch-icon-precomp
# ...
